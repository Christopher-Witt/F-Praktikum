# %%
x_list = [x * 2 for x in x_list]
y_List = [y * 2 for y in y_List]
z_list = [z * 2 for z in z_list]

import matplotlib.pyplot as plt
plt.plot(x_list, y_List, label="line 1", color='r', marker='o')
plt.plot(x_list, z_list, label="line 2", color='g', marker='o')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("My first graph")
plt.legend()
plt.show()
